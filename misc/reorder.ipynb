# %% [markdown]
# ## Get the old and new rods

# %%
class Bar():
    
    def __init__(self, label, length):
        
        self.label    = label
        self.length   = length
        self.has_pair = False

# %%
old_bars = []
with open ('old_rod.txt') as file:
    lines = file.read().split('\n')
    
    for i in range(0, len(lines), 4):
        length_list = [float(v) for v in lines[i+2][8:].split(', ')]
        label_list  = lines[i+3][7:].split(', ')

        for label, length in zip(label_list, length_list):
            bar = Bar(label, length)
            old_bars.append(bar)

# %%
new_bars = []
with open ('rod.dat') as file:
    lines = file.read().split('\n')
    
    for i in range(0, len(lines), 4):
        length_list = [float(v) for v in lines[i+2][8:].split(', ')]
        label_list  = lines[i+3][7:].split(', ')

        for label, length in zip(label_list, length_list):
            bar = Bar(label, length)
            new_bars.append(bar)

# %%
len(new_bars)
# Out:
# 178

# %% [markdown]
# ## Creare fully reusable rod pairs

# %%
class Pair():
    
    def __init__(self, old_bar, new_bar):
        
        self.old_bar = old_bar
        self.new_bar = new_bar
        
    def __repr__(self):
        
        return 'old_index: %s, new_index: %s, length: %.2f' % (self.old_bar.label, self.new_bar.label, self.new_bar.length)

# %%
print(len(new_bars), len(old_bars))
# Out:
# 178 186

# %%
tolerance = 1

pair_list = []

for new_bar in new_bars:

    for old_bar in old_bars:
        
        if not old_bar.has_pair and abs(old_bar.length - new_bar.length) <= tolerance:
            
            pair = Pair(old_bar, new_bar)
            old_bar.has_pair = True
            new_bar.has_pair = True
            pair_list.append(pair)
            break

# %%
print(len(pair_list))
# Out:
# 83

# %%
print(len(old_bars))
old_bars =  [b for b in old_bars if not b.has_pair]
print(len(old_bars))
# Out:
# 186
# 103

# %%
print(len(new_bars))
new_bars =  [b for b in new_bars if not b.has_pair]
print(len(new_bars))
# Out:
# 178
# 95

# %% [markdown]
# ## Bin-packing

# %%
class Rod(object):
    
    def __init__(self, length, label):
        
        self.length = length
        self.label  = label

class Bin(object):

    def __init__(self, length, old_index):
    
        self.items = []
        self.sum   = 0
        self.length = length
        self.old_index = old_index

    def append(self, item):
        
        self.items.append(item)
        self.sum += item.length

    def result(self, index):
        
        total = self.total_length()
        
        lengths = []
        labels  = []
        place_holder = 'INDEX: %d, ROD_ID: %s, ROD_LENGTH: %.2f \nTOTAL: %.2f'
        
        ph_length = '\nLENGTH: '
        ph_label  = '\nLABEL: '
        
        for item in self.items:
            ph_length += '%.2f, '
            ph_label  += '%s, '
            lengths.append(item.length)
            labels.append(item.label)
            
        if index > 0:
            place_holder = '\n' + place_holder
            
        ph_length = ph_length[:-2]
        ph_label  = ph_label[:-2]
        
        place_holder = place_holder + ph_length + ph_label + '\n'
        return place_holder % tuple([index, self.old_index, self.length, total] + lengths + labels)

    def total_length(self):
        
        total = 0
        
        for item in self.items:
            total += item.length
            
        return total

# %%
import operator

new_bars.sort(key=operator.attrgetter('length'), reverse=True)
old_bars.sort(key=operator.attrgetter('length'), reverse=True)

# %%
bins = []

old_bar_index = 0

for new_bar in new_bars:
    
    item = Rod(new_bar.length, new_bar.label)

    for bin in bins:

        if bin.sum + item.length <= bin.length:
            bin.append(item)
            break

    else:
        
        old_bar = old_bars[old_bar_index]
        bin = Bin(old_bar.length, old_bar.label)
        bin.append(item)
        bins.append(bin)
        old_bar_index += 1

result = ''
sum_length = 0
for i, bin in enumerate(bins):
    
    result += bin.result(i)
    total = bin.total_length()
    sum_length += total
    
print(result)
# Out:
# INDEX: 0, ROD_ID: 0863, ROD_LENGTH: 1189.13
# TOTAL: 1185.20
# LENGTH: 535.75, 534.93, 114.52
# LABEL: 0036, 0236, 4354
#
# INDEX: 1, ROD_ID: 1863, ROD_LENGTH: 970.29
# TOTAL: 933.06
# LENGTH: 505.66, 427.40
# LABEL: 3863, 2346
#
# INDEX: 2, ROD_ID: 1363, ROD_LENGTH: 831.62
# TOTAL: 831.50
# LENGTH: 486.27, 345.23
# LABEL: 2036, 0011
#
# INDEX: 3, ROD_ID: 4063, ROD_LENGTH: 830.43
# TOTAL: 828.63
# LENGTH: 475.50, 353.13
# LABEL: 6263, 2853
#
# INDEX: 4, ROD_ID: 5863, ROD_LENGTH: 768.14
# TOTAL: 765.41
# LENGTH: 427.08, 338.33
# LABEL: 3136, 1723
#
# INDEX: 5, ROD_ID: 5663, ROD_LENGTH: 715.93
# TOTAL: 712.05
# LENGTH: 411.74, 300.31
# LABEL: 1122, 2135
#
# INDEX: 6, ROD_ID: 4863, ROD_LENGTH: 615.58
# TOTAL: 612.69
# LENGTH: 404.44, 208.25
# LABEL: 3862, 4254
#
# INDEX: 7, ROD_ID: 3563, ROD_LENGTH: 596.53
# TOTAL: 591.77
# LENGTH: 376.78, 214.99
# LABEL: 1035, 1529
#
# INDEX: 8, ROD_ID: 0036, ROD_LENGTH: 539.75
# TOTAL: 538.70
# LENGTH: 368.82, 169.88
# LABEL: 0611, 2031
#
# INDEX: 9, ROD_ID: 0236, ROD_LENGTH: 538.93
# TOTAL: 536.11
# LENGTH: 368.40, 167.71
# LABEL: 4163, 3337
#
# INDEX: 10, ROD_ID: 3863, ROD_LENGTH: 509.66
# TOTAL: 508.95
# LENGTH: 365.72, 143.23
# LABEL: 3653, 0203
#
# INDEX: 11, ROD_ID: 2036, ROD_LENGTH: 490.27
# TOTAL: 486.18
# LENGTH: 355.26, 130.92
# LABEL: 1335, 3638
#
# INDEX: 12, ROD_ID: 6263, ROD_LENGTH: 479.50
# TOTAL: 478.79
# LENGTH: 355.11, 123.68
# LABEL: 3536, 3637
#
# INDEX: 13, ROD_ID: 2346, ROD_LENGTH: 431.40
# TOTAL: 346.38
# LENGTH: 346.38
# LABEL: 0220
#
# INDEX: 14, ROD_ID: 3136, ROD_LENGTH: 431.08
# TOTAL: 344.85
# LENGTH: 344.85
# LABEL: 3445
#
# INDEX: 15, ROD_ID: 1746, ROD_LENGTH: 417.98
# TOTAL: 332.00
# LENGTH: 332.00
# LABEL: 0517
#
# INDEX: 16, ROD_ID: 1122, ROD_LENGTH: 415.74
# TOTAL: 329.98
# LENGTH: 329.98
# LABEL: 4562
#
# INDEX: 17, ROD_ID: 1738, ROD_LENGTH: 373.25
# TOTAL: 322.72
# LENGTH: 322.72
# LABEL: 4552
#
# INDEX: 18, ROD_ID: 0611, ROD_LENGTH: 372.82
# TOTAL: 321.83
# LENGTH: 321.83
# LABEL: 2136
#
# INDEX: 19, ROD_ID: 4163, ROD_LENGTH: 372.40
# TOTAL: 315.51
# LENGTH: 315.51
# LABEL: 1937
#
# INDEX: 20, ROD_ID: 1335, ROD_LENGTH: 359.26
# TOTAL: 308.71
# LENGTH: 308.71
# LABEL: 1936
#
# INDEX: 21, ROD_ID: 3536, ROD_LENGTH: 359.11
# TOTAL: 298.51
# LENGTH: 298.51
# LABEL: 3240
#
# INDEX: 22, ROD_ID: 2853, ROD_LENGTH: 357.13
# TOTAL: 291.04
# LENGTH: 291.04
# LABEL: 4662
#
# INDEX: 23, ROD_ID: 0220, ROD_LENGTH: 350.38
# TOTAL: 290.36
# LENGTH: 290.36
# LABEL: 5562
#
# INDEX: 24, ROD_ID: 0011, ROD_LENGTH: 349.23
# TOTAL: 289.80
# LENGTH: 289.80
# LABEL: 4247
#
# INDEX: 25, ROD_ID: 3445, ROD_LENGTH: 348.85
# TOTAL: 286.84
# LENGTH: 286.84
# LABEL: 0811
#
# INDEX: 26, ROD_ID: 1035, ROD_LENGTH: 348.81
# TOTAL: 279.96
# LENGTH: 279.96
# LABEL: 1130
#
# INDEX: 27, ROD_ID: 1723, ROD_LENGTH: 342.33
# TOTAL: 279.31
# LENGTH: 279.31
# LABEL: 1127
#
# INDEX: 28, ROD_ID: 0517, ROD_LENGTH: 336.00
# TOTAL: 278.50
# LENGTH: 278.50
# LABEL: 3846
#
# INDEX: 29, ROD_ID: 4562, ROD_LENGTH: 333.98
# TOTAL: 277.56
# LENGTH: 277.56
# LABEL: 5255
#
# INDEX: 30, ROD_ID: 4552, ROD_LENGTH: 326.72
# TOTAL: 271.08
# LENGTH: 271.08
# LABEL: 2541
#
# INDEX: 31, ROD_ID: 3641, ROD_LENGTH: 320.04
# TOTAL: 267.03
# LENGTH: 267.03
# LABEL: 1832
#
# INDEX: 32, ROD_ID: 1937, ROD_LENGTH: 319.51
# TOTAL: 265.19
# LENGTH: 265.19
# LABEL: 4460
#
# INDEX: 33, ROD_ID: 4749, ROD_LENGTH: 314.19
# TOTAL: 260.41
# LENGTH: 260.41
# LABEL: 1119
#
# INDEX: 34, ROD_ID: 1129, ROD_LENGTH: 307.17
# TOTAL: 258.88
# LENGTH: 258.88
# LABEL: 0920
#
# INDEX: 35, ROD_ID: 2135, ROD_LENGTH: 304.31
# TOTAL: 251.45
# LENGTH: 251.45
# LABEL: 0111
#
# INDEX: 36, ROD_ID: 3446, ROD_LENGTH: 295.61
# TOTAL: 234.75
# LENGTH: 234.75
# LABEL: 1523
#
# INDEX: 37, ROD_ID: 4662, ROD_LENGTH: 295.04
# TOTAL: 233.18
# LENGTH: 233.18
# LABEL: 0309
#
# INDEX: 38, ROD_ID: 5562, ROD_LENGTH: 294.36
# TOTAL: 233.13
# LENGTH: 233.13
# LABEL: 4347
#
# INDEX: 39, ROD_ID: 4247, ROD_LENGTH: 293.80
# TOTAL: 232.16
# LENGTH: 232.16
# LABEL: 0117
#
# INDEX: 40, ROD_ID: 3537, ROD_LENGTH: 287.89
# TOTAL: 225.02
# LENGTH: 225.02
# LABEL: 3650
#
# INDEX: 41, ROD_ID: 1127, ROD_LENGTH: 283.31
# TOTAL: 224.78
# LENGTH: 224.78
# LABEL: 4349
#
# INDEX: 42, ROD_ID: 3846, ROD_LENGTH: 282.50
# TOTAL: 223.99
# LENGTH: 223.99
# LABEL: 2945
#
# INDEX: 43, ROD_ID: 5255, ROD_LENGTH: 281.56
# TOTAL: 223.45
# LENGTH: 223.45
# LABEL: 5363
#
# INDEX: 44, ROD_ID: 6062, ROD_LENGTH: 275.10
# TOTAL: 222.03
# LENGTH: 222.03
# LABEL: 2536
#
# INDEX: 45, ROD_ID: 2541, ROD_LENGTH: 275.08
# TOTAL: 214.76
# LENGTH: 214.76
# LABEL: 2933
#
# INDEX: 46, ROD_ID: 4652, ROD_LENGTH: 269.21
# TOTAL: 214.02
# LENGTH: 214.02
# LABEL: 1415
#
# INDEX: 47, ROD_ID: 4460, ROD_LENGTH: 269.19
# TOTAL: 213.71
# LENGTH: 213.71
# LABEL: 5156
#
# INDEX: 48, ROD_ID: 0926, ROD_LENGTH: 263.45
# TOTAL: 199.20
# LENGTH: 199.20
# LABEL: 4548
#
# INDEX: 49, ROD_ID: 0920, ROD_LENGTH: 262.88
# TOTAL: 198.25
# LENGTH: 198.25
# LABEL: 0818
#
# INDEX: 50, ROD_ID: 1930, ROD_LENGTH: 253.87
# TOTAL: 196.91
# LENGTH: 196.91
# LABEL: 0622
#
# INDEX: 51, ROD_ID: 5053, ROD_LENGTH: 246.98
# TOTAL: 196.91
# LENGTH: 196.91
# LABEL: 1922
#
# INDEX: 52, ROD_ID: 3452, ROD_LENGTH: 243.09
# TOTAL: 191.99
# LENGTH: 191.99
# LABEL: 4051
#
# INDEX: 53, ROD_ID: 2329, ROD_LENGTH: 240.36
# TOTAL: 191.61
# LENGTH: 191.61
# LABEL: 2122
#
# INDEX: 54, ROD_ID: 4347, ROD_LENGTH: 237.13
# TOTAL: 191.12
# LENGTH: 191.12
# LABEL: 4048
#
# INDEX: 55, ROD_ID: 2439, ROD_LENGTH: 236.57
# TOTAL: 190.72
# LENGTH: 190.72
# LABEL: 2641
#
# INDEX: 56, ROD_ID: 0117, ROD_LENGTH: 236.16
# TOTAL: 189.43
# LENGTH: 189.43
# LABEL: 3547
#
# INDEX: 57, ROD_ID: 5363, ROD_LENGTH: 227.45
# TOTAL: 179.81
# LENGTH: 179.81
# LABEL: 2435
#
# INDEX: 58, ROD_ID: 2536, ROD_LENGTH: 226.03
# TOTAL: 179.80
# LENGTH: 179.80
# LABEL: 2740
#
# INDEX: 59, ROD_ID: 2236, ROD_LENGTH: 219.20
# TOTAL: 179.18
# LENGTH: 179.18
# LABEL: 0711
#
# INDEX: 60, ROD_ID: 1529, ROD_LENGTH: 218.99
# TOTAL: 167.52
# LENGTH: 167.52
# LABEL: 5459
#
# INDEX: 61, ROD_ID: 2933, ROD_LENGTH: 218.76
# TOTAL: 167.19
# LENGTH: 167.19
# LABEL: 2334
#
# INDEX: 62, ROD_ID: 1415, ROD_LENGTH: 218.02
# TOTAL: 163.68
# LENGTH: 163.68
# LABEL: 1221
#
# INDEX: 63, ROD_ID: 4556, ROD_LENGTH: 216.31
# TOTAL: 162.69
# LENGTH: 162.69
# LABEL: 3033
#
# INDEX: 64, ROD_ID: 5357, ROD_LENGTH: 211.12
# TOTAL: 153.78
# LENGTH: 153.78
# LABEL: 5354
#
# INDEX: 65, ROD_ID: 1118, ROD_LENGTH: 209.70
# TOTAL: 153.45
# LENGTH: 153.45
# LABEL: 0209
#
# INDEX: 66, ROD_ID: 2122, ROD_LENGTH: 195.61
# TOTAL: 152.29
# LENGTH: 152.29
# LABEL: 2631
#
# INDEX: 67, ROD_ID: 4048, ROD_LENGTH: 195.12
# TOTAL: 146.31
# LENGTH: 146.31
# LABEL: 0912
#
# INDEX: 68, ROD_ID: 2641, ROD_LENGTH: 194.72
# TOTAL: 145.81
# LENGTH: 145.81
# LABEL: 1618
#
# INDEX: 69, ROD_ID: 3547, ROD_LENGTH: 193.43
# TOTAL: 142.81
# LENGTH: 142.81
# LABEL: 3744
#
# INDEX: 70, ROD_ID: 2432, ROD_LENGTH: 184.80
# TOTAL: 137.73
# LENGTH: 137.73
# LABEL: 0612
#
# INDEX: 71, ROD_ID: 1827, ROD_LENGTH: 184.17
# TOTAL: 137.36
# LENGTH: 137.36
# LABEL: 0001
#
# INDEX: 72, ROD_ID: 2435, ROD_LENGTH: 183.81
# TOTAL: 130.73
# LENGTH: 130.73
# LABEL: 4555
#
# INDEX: 73, ROD_ID: 2740, ROD_LENGTH: 183.80
# TOTAL: 128.90
# LENGTH: 128.90
# LABEL: 0715
#
# INDEX: 74, ROD_ID: 0711, ROD_LENGTH: 183.18
# TOTAL: 121.29
# LENGTH: 121.29
# LABEL: 0816
#
# INDEX: 75, ROD_ID: 4856, ROD_LENGTH: 177.69
# TOTAL: 108.15
# LENGTH: 108.15
# LABEL: 5658
#
# INDEX: 76, ROD_ID: 5156, ROD_LENGTH: 177.46
# TOTAL: 107.04
# LENGTH: 107.04
# LABEL: 0507
#
# INDEX: 77, ROD_ID: 0003, ROD_LENGTH: 177.17
# TOTAL: 106.24
# LENGTH: 106.24
# LABEL: 1222
#
# INDEX: 78, ROD_ID: 3141, ROD_LENGTH: 175.26
# TOTAL: 103.51
# LENGTH: 103.51
# LABEL: 4959
#
# INDEX: 79, ROD_ID: 0312, ROD_LENGTH: 171.69
# TOTAL: 103.14
# LENGTH: 103.14
# LABEL: 1423
#
# INDEX: 80, ROD_ID: 5459, ROD_LENGTH: 171.52
# TOTAL: 96.75
# LENGTH: 96.75
# LABEL: 5060

# %% [markdown]
# ## Write

# %%
with open('./final_rod.dat', 'w') as file:
    file.write(result)

# %%
pair_result = ''

for p in pair_list:
    pair_result += p.__repr__() + '\n'

with open('./final_pair_rod.dat', 'w') as file:
    file.write(pair_result)
